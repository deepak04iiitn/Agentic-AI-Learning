# %%
### TextLoader

from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)

# %% [markdown]
# ### Data Ingestion

# %%
#### Document data structure

from langchain_core.documents import Document

# %%
from langchain_core.documents import Document

doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Krish Naik",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file

import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# C:\Users\dky42\AppData\Local\Temp\ipykernel_2504\2416650908.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 0}, page_content='Latest Trends in Biomedical \nInstrumentation'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 1}, page_content='Introduction\n• Biomedical Instrumentation = medical devices +\nelectronics + sensors\n• Used for diagnosis, monitoring, therapy\n• Rapid evolution due to:\n– AI & Data Science\n– IoT\n– Miniaturization\n• Focus: Smart, real-time, patient-centric healthcare'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 2}, page_content='Need for Advanced Instrumentation\n• Rising chronic diseases \n• Remote healthcare demand \n• Precision medicine \n• Real-time monitoring necessity \n• Cost-effective healthcare solutions'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 3}, page_content='Classification of Biomedical \nInstruments\n• Diagnostic (ECG, MRI) \n• Monitoring (ICU monitors) \n• Therapeutic (Pacemakers) \n• Imaging systems \n• Wearable devices'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 4}, page_content='Trend 1 – Wearable Health Devices\n• Smart watches, fitness bands \n• Continuous monitoring: \n– Heart rate \n– SpO₂ \n– Sleep patterns \n• Examples: \n– Apple Watch Series 9 \n– Fitbit Charge 6 \n• Advantage: Preventive healthcare'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 5}, page_content='Wearable Device Working\n• Sensors → Signal acquisition \n• Signal conditioning → Filtering \n• ADC → Digital conversion \n• Microcontroller → Processing \n• Wireless → Data transmission'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 6}, page_content='Trend 2 – Internet of Medical Things \n(IoMT)\n• Connected medical devices via internet \n• Real-time data sharing \n• Remote diagnosis \n• Applications:\n– Smart ICU \n– Remote patient monitoring \n– Home healthcare'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 7}, page_content='IoMT Architecture\n• Data analytics \n• Alerts & decision making \nCLOUD\nSENSORS\nGATEWAY\nDOCTOR'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 8}, page_content='Slide 9: Trend 3 – Artificial Intelligence \n(AI)\n• AI in diagnostics \n• Pattern recognition \n• Disease prediction \n• Examples:\n– Cancer detection \n– ECG analysis \n– Radiology imaging'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 9}, page_content='AI in ECG Analysis\n• Automated arrhythmia detection \n• Faster diagnosis \n• Reduced human error'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 10}, page_content='Trend 4 – Telemedicine\n• Remote consultation \n• Video conferencing \n• Digital prescriptions \n• Benefits:\n– Rural healthcare access \n– Time & cost saving'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 11}, page_content='Trend 5 – Point of Care (POC) Devices\n• Portable diagnostic devices \n• Immediate results \n• Examples:\n– Glucose monitor \n– Portable ECG'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 12}, page_content='Trend 6 – Implantable Devices\n• Pacemakers \n• Neurostimulators \n• Cochlear implants \n• Long-term monitoring & therapy'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 13}, page_content='Trend 7 – Robotics in Surgery\n• Precision surgery \n• Minimally invasive \n• Example:\n– Da Vinci Surgical System'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 14}, page_content='Slide 15: Trend 8 – Biosensors\n• Detect biological parameters \n• High sensitivity \n• Applications:\n– Glucose monitoring \n– DNA detection'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 15}, page_content='Trend 9 – Lab-on-Chip Technology\n• Miniaturized labs \n• Fast diagnostics \n• Low sample requirement'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 16}, page_content='Challenges\n• Data security (Cyber threats) \n• High cost \n• Regulatory approvals \n• Accuracy & reliability'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 17}, page_content='Future Scope\n• Smart hospitals \n• AI-driven diagnosis \n• Personalized medicine \n• Fully automated healthcare systems'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 18}, page_content=''),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 19}, page_content=''),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 20}, page_content=''),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 21}, page_content=''),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® PowerPoint® 2016', 'creationdate': '2026-04-22T05:28:04+00:00', 'source': '..\\data\\pdf\\pdf1.pdf', 'file_path': '..\\data\\pdf\\pdf1.pdf', 'total_pages': 23, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-22T05:28:04+00:00', 'trapped': '', 'modDate': 'D:20260422052804Z', 'creationDate': "D:20260422052804+00'00'", 'page': 22}, page_content='')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
